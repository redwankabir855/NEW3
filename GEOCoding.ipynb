# %%
import pandas as pd
import json
import requests

# %%
a=pd.read_csv("C:/Users/redwa/Dropbox/York University/Academic/Sem 2/MBAN 6090 A  Analytics Consulting Project/Data Sets/Bank Branch Locations/RBC Locations.csv" )

# %%
a
# Out:
#                                           Address             City Province  \
# 0                   1789 Lonsdale Ave - 2nd floor  North Vancouver       BC
# 1            1055 West Georgia Street - 5th floor        Vancouver       BC
# 2                450 SW Marine Drive - 16th floor        Vancouver       BC
# 3                         101 - 8411 200th street          Langley       BC
# 4                                 707 Fort Street         Victoria       BC
# 5                               1665 Ellis Street          Kelowna       BC
# 6                   Suite 2400, 10111 2014 Ave NW         Edmonton       AB
# 7                      335 8th Ave SW - suite 300          Calgary       AB
# 8                   Suite 200, 220 Portage Avenue         Winnipeg       MB
# 9                       154 1st Ave S - 4th floor        Saskatoon       SK
# 10                         Suite 200, 2010 11 Ave           Regina       SK
# ...

# %% [markdown]
# for i, row in a.iterrows():
#     apiAddress = str(a.at[i,'ADDRESS'])+','+str(a.at[i,'CITY'])+','+str(a.at[i,'PROV'])+','+str(a.at[i,'P.CODE'])
#
#     print(apiAddress)

# %% [markdown]
#  parameters = {
#         "key": "5lSsRua2rDlskWe9hVcvUXq5TB5u4U6J",
#         "location": 'apiAddress'
#     }

# %% [markdown]
# response = requests.get("http://www.mapquestapi.com/geocoding/v1/batch", params=parameters)
# print(response)

# %% [markdown]
# print(response.text)

# %% [markdown]
# data = response.text
# dataJ = json.loads(data)['results']
# lat = (dataJ[0]['locations'][0]['latLng']['lat'])
# lng = (dataJ[0]['locations'][0]['latLng']['lng'])
# print(lat, lng)

# %% [markdown]
# a.at[i,'lat'] = lat
# a.at[i,'lng'] = lng

# %% [markdown]
# a

# %%
for i, row in a.iterrows():
    apiAddress = str(a.at[i,'Address'])+','+str(a.at[i,'City'])+','+str(a.at[i,'Province'])+','+str(a.at[i,'Postal Code'])
    parameters = {
        "key": "5lSsRua2rDlskWe9hVcvUXq5TB5u4U6J",
        "location": apiAddress
    }

    response = requests.get("http://www.mapquestapi.com/geocoding/v1/address", params=parameters)
    print(response)
    data = response.text
    dataJ = json.loads(data)['results']
    lat = (dataJ[0]['locations'][0]['latLng']['lat'])
    lng = (dataJ[0]['locations'][0]['latLng']['lng'])
    
    a.at[i,'lat'] = lat
    a.at[i,'lng'] = lng
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
a
# Out:
#                                           Address             City Province  \
# 0                   1789 Lonsdale Ave - 2nd floor  North Vancouver       BC
# 1            1055 West Georgia Street - 5th floor        Vancouver       BC
# 2                450 SW Marine Drive - 16th floor        Vancouver       BC
# 3                         101 - 8411 200th street          Langley       BC
# 4                                 707 Fort Street         Victoria       BC
# 5                               1665 Ellis Street          Kelowna       BC
# 6                   Suite 2400, 10111 2014 Ave NW         Edmonton       AB
# 7                      335 8th Ave SW - suite 300          Calgary       AB
# 8                   Suite 200, 220 Portage Avenue         Winnipeg       MB
# 9                       154 1st Ave S - 4th floor        Saskatoon       SK
# 10                         Suite 200, 2010 11 Ave           Regina       SK
# ...

# %%
a.to_csv('RBC_new set.csv')
